# %% [markdown]
# # Assignment 1
# ### Understanding Uncertainty
# ### Due 9/5

# %% [markdown]
# 1. Create a new public repo on Github under your account. Include a readme file.
# 2. Clone it to your machine. Put this file into that repo.
# 3. Use the following function to download the example data for the course:

# %%
def download_data(force=False):
    """Download and extract course data from Zenodo."""
    import urllib.request, zipfile, os
    
    zip_path = 'data.zip'
    data_dir = 'data'
    
    if not os.path.exists(zip_path) or force:
        print("Downloading course data")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/16954427/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")
    else:
        print("Download file already exists")
        
    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")
    else:
        print("Data directory already exists")

download_data()
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# 4. Open one of the datasets using Pandas:
#     1. `ames_prices.csv`: Housing characteristics and prices
#     2. `college_completion.csv`: Public, nonprofit, and for-profit educational institutions, graduation rates, and financial aid
#     3. `ForeignGifts_edu.csv`: Monetary and in-kind transfers from foreign entities to U.S. educational institutions
#     4. `iowa.csv`: Liquor sales in Iowa, at the transaction level
#     5. `metabric.csv`: Cancer patient and outcome data
#     6. `mn_police_use_of_force.csv`: Records of physical altercations between Minnessota police and private citizens
#     7. `nhanes_data_17_18.csv`: National Health and Nutrition Examination Survey
#     8. `tuna.csv`: Yellowfin Tuna Genome (I don't recommend this one; it's just a sequence of G, C, A, T )
#     9. `va_procurement.csv`: Public spending by the state of Virginia

# %%
import pandas as pd
import numpy as np

health = pd.read_csv('data/nhanes_data_17_18.csv')
health.head()
# Out:
# /tmp/ipykernel_52269/1551898876.py:4: DtypeWarning: Columns (142) have mixed types. Specify dtype option on import or set low_memory=False.
#   health = pd.read_csv('data/nhanes_data_17_18.csv')
#       SEQN GeneralHealthCondition  EverBreastfedOrFedBreastmilk  \
# 0  93703.0                    NaN                           1.0
# 1  93704.0                    NaN                           1.0
# 2  93705.0                   Good                           NaN
# 3  93706.0              Very good                           NaN
# 4  93707.0                   Good                           NaN
#
#    AgeStoppedBreastfeedingdays  AgeFirstFedFormuladays  \
# 0                        273.0                     1.0
# 1                         60.0                     3.0
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
# ...

# %% [markdown]
# 5. Pick two or three variables and briefly analyze them
#     - Is it a categorical or numeric variable?
#     - How many missing values are there? (`df['var'].isna()` and `np.sum()`)
#     - If categorical, tabulate the values (`df['var'].value_counts()`) and if numeric, get a summary (`df['var'].describe()`)

# %%
#General health condition

# print(health['GeneralHealthCondition'].info(), end='\n\n')
# print(health['GeneralHealthCondition'].describe(), end='\n\n')
print(health['GeneralHealthCondition'].head())
# print(health['GeneralHealthCondition'].tail())
print('This is a categorical variable.')
print('Number of missing values: ', health['GeneralHealthCondition'].isna().sum())
print(health['GeneralHealthCondition'].value_counts())

print('\n\n')
#Sleep Hours Weekdays or Workdays

print(health['SleepHoursWeekdaysOrWorkdays'].head())
print('This is a numeric variable')
print('Number of missing values: ', health['SleepHoursWeekdaysOrWorkdays'].isna().sum())
print(health['SleepHoursWeekdaysOrWorkdays'].describe())
# Out:
# 0          NaN
# 1          NaN
# 2         Good
# 3    Very good
# 4         Good
# Name: GeneralHealthCondition, dtype: object
# This is a categorical variable.
# Number of missing values:  2402
# GeneralHealthCondition
# Good         2454
# Very good    1544
# Fair or      1175
# Excellent     619
# Poor?         172
# Name: count, dtype: int64
#
#
#
# 0     NaN
# 1     NaN
# 2     8.0
# 3    10.5
# 4     NaN
# Name: SleepHoursWeekdaysOrWorkdays, dtype: float64
# This is a numeric variable
# Number of missing values:  2583
# count    5783.000000
# mean        7.643005
# std         1.672216
# min         2.000000
# 25%         7.000000
# 50%         8.000000
# 75%         8.500000
# max        14.000000
# Name: SleepHoursWeekdaysOrWorkdays, dtype: float64

# %% [markdown]
# 6. What are some questions and prediction tools you could create using these data? Who would the stakeholder be for that prediction tool? What practical or ethical questions would it create? What other data would you want, that are not available in your data?

# %% [markdown]
# - How does the amount of sleep one gets affect their general health condition?
#     - Prediction tool: Use a linear regression model to see if there is a correlation between higher hours of sleep and better health conditions. This would also require giving the better health conditions numerical values to work.
#     - The stakeholder might be a doctor's office looking to create a guideline for how much sleep they should recommend to patients. Some practical and ethical questions are:
#         - How much do you generalize recommendation across people of different genders, races, ethnicities, etc.?
# - How do the various diets asked about affect cholesterol levels, A1C levels, or if the patient has been told they are at risk for diabetes?
#     - Try to use a combination of these factors to predict if someone has diabetes.
#     - A stakeholder could be a drug company looking to target potential customers.
#     - This raises the eithical question of ensuring no personal information is shared about the people the data is about.
#     - Also, can this company purposefully manipulate the data to show that their product works better than another, thereby convincing people to choose a worse product.

# %% [markdown]
# 7. Commit your work to the repo (`git commit -am 'Finish assignment'` at the command line, or use the Git panel in VS Code). Push your work back to Github and submit the link on Canvas in the assignment tab.
